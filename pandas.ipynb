# %%
import pandas as pd

# %% [markdown]
# - 文件的读取
# pd.read_csv("FileName")
# - 类型的检测
# type()
# - 数字类型的检测
# dtype()
# - 显示前n条数据
# Bianliang_Name.head(n)
# - 显示后n条数据
# Bianliang_Name.tail(n)
# - 显示特定行的数据
# print(Bianliang_Name.columns)
# - 显示读取的数据的维度
# print(Biangliang_Name.shape)

# %%
Zhong_Yi = pd.read_excel("data.xls")
print(Zhong_Yi)
print("*"*40)
print(type(Zhong_Yi))
print("*"*40)
print(Zhong_Yi.dtypes)
# Out:
#      肝气郁结证型系数  热毒蕴结证型系数  冲任失调证型系数  气血两虚证型系数  脾胃虚弱证型系数  肝肾阴虚证型系数 病程阶段 TNM分期  \
# 0       0.056     0.460     0.281     0.352     0.119     0.350   S4    H4
# 1       0.488     0.099     0.283     0.333     0.116     0.293   S4    H4
# 2       0.107     0.008     0.204     0.150     0.032     0.159   S4    H4
# 3       0.322     0.208     0.305     0.130     0.184     0.317   S4    H4
# 4       0.242     0.280     0.131     0.210     0.191     0.351   S4    H4
# 5       0.389     0.112     0.456     0.277     0.185     0.396   S4    H4
# 6       0.246     0.202     0.277     0.178     0.237     0.483   S4    H4
# 7       0.330     0.125     0.356     0.268     0.366     0.397   S4    H4
# 8       0.257     0.314     0.328     0.140     0.128     0.335   S4    H4
# 9       0.205     0.330     0.253     0.295     0.115     0.224   S4    H4
# 10      0.330     0.161     0.232     0.122     0.133     0.394   S4    H4
# ...

# %%
print(Zhong_Yi.loc[0])
print("*"*40)
b = ["肝气郁结证型系数","热毒蕴结证型系数"]
a = Zhong_Yi[b]
print(a)
# Out:
# 肝气郁结证型系数     0.056
# 热毒蕴结证型系数      0.46
# 冲任失调证型系数     0.281
# 气血两虚证型系数     0.352
# 脾胃虚弱证型系数     0.119
# 肝肾阴虚证型系数      0.35
# 病程阶段            S4
# TNM分期           H4
# 转移部位            R1
# 确诊后几年发现转移       J1
# Name: 0, dtype: object
# ****************************************
#      肝气郁结证型系数  热毒蕴结证型系数
# 0       0.056     0.460
# 1       0.488     0.099
# 2       0.107     0.008
# 3       0.322     0.208
# 4       0.242     0.280
# 5       0.389     0.112
# 6       0.246     0.202
# 7       0.330     0.125
# 8       0.257     0.314
# 9       0.205     0.330
# 10      0.330     0.161
# 11      0.235     0.170
# 12      0.267     0.355
# 13      0.281     0.174
# 14      0.184     0.258
# 15      0.271     0.148
# 16      0.100     0.101
# 17      0.173     0.187
# 18      0.302     0.780
# 19      0.176     0.690
# 20      0.172     0.503
# 21      0.195     0.369
# 22      0.281     0.322
# 23      0.245     0.111
# 24      0.156     0.259
# 25      0.168     0.398
# ...

# %%
name = Zhong_Yi.columns.tolist()
print(name)
GB = []

for c in name:
    if c.endswith("证型系数"):
        GB.append(c)
GB_df = Zhong_Yi[GB]
print(GB_df.head(3))
# Out:
# ['肝气郁结证型系数', '热毒蕴结证型系数', '冲任失调证型系数', '气血两虚证型系数', '脾胃虚弱证型系数', '肝肾阴虚证型系数', '病程阶段', 'TNM分期', '转移部位', '确诊后几年发现转移']
#    肝气郁结证型系数  热毒蕴结证型系数  冲任失调证型系数  气血两虚证型系数  脾胃虚弱证型系数  肝肾阴虚证型系数
# 0     0.056     0.460     0.281     0.352     0.119     0.350
# 1     0.488     0.099     0.283     0.333     0.116     0.293
# 2     0.107     0.008     0.204     0.150     0.032     0.159

# %%
#升序排序
Zhong_Yi.sort_values("肝气郁结证型系数",inplace=True)
print(Zhong_Yi["肝气郁结证型系数"])
print("*"*20)
#降序排序
Zhong_Yi.sort_values("肝气郁结证型系数",inplace=True,ascending=False)
print(Zhong_Yi["肝气郁结证型系数"])
# Out:
# 412    0.026
# 598    0.033
# 372    0.034
# 784    0.041
# 409    0.042
# 40     0.042
# 558    0.045
# 595    0.045
# 744    0.049
# 781    0.049
# 37     0.053
# 223    0.054
# 226    0.055
# 0      0.056
# 186    0.057
# 388    0.083
# 374    0.085
# 499    0.087
# 554    0.087
# 574    0.089
# 541    0.089
# 560    0.089
# 458    0.091
# 539    0.092
# 685    0.092
# 725    0.093
# 498    0.094
# 684    0.094
# 546    0.095
# 727    0.097
#        ...
# 347    0.400
# 543    0.400
# 729    0.408
# 700    0.411
# 417    0.411
# 886    0.415
# 915    0.415
# 171    0.417
# 603    0.417
# 422    0.417
# 142    0.418
# 328    0.420
# 608    0.424
# 794    0.425
# 789    0.426
# 236    0.427
# 496    0.429
# 231    0.432
# 45     0.432
# 682    0.432
# 50     0.433
# 357    0.435
# 868    0.439
# 124    0.448
# 310    0.456
# 373    0.474
# 559    0.487
# 1      0.488
# 745    0.488
# 187    0.504
# Name: 肝气郁结证型系数, Length: 930, dtype: float64
# ********************
# 187    0.504
# ...
