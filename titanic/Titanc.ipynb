# %%
import numpy as np
import pandas as pd

# %%
T_Survival = pd.read_csv("train.csv")
print(T_Survival.head())
print(T_Survival.tail())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# ...

# %%
#数据中NAN的处理——找到数据中所有的NAN的值
age = T_Survival["Age"]
#print(age.loc[0:10])
age_is_null = pd.isnull(age)
#print(age_is_null)
age_null_true = age[age_is_null]
#print(age_null_true)
#缺失值的处理
#未处理缺失值的效果
#mean_age = sum(T_Survival["Age"])/len(T_Survival["Age"])
#print(mean_age)
#处理之后的效果
good_ages = T_Survival["Age"][age_is_null == False]
#print(good_ages)
correct_mean_age = T_Survival["Age"].mean()
print(correct_mean_age)
# Out:
# 29.69911764705882

# %%
# 不同舱位获救的比例
passenger_survival = T_Survival.pivot_table(index="Pclass",values="Survived",aggfunc=np.mean)
print(passenger_survival)
print("*"*20)
#每个舱位的平均票价
fare_class = T_Survival.pivot_table(index="Pclass",values="Fare",aggfunc=np.mean)
print(fare_class)
print("*"*20)
#每个舱位的平均年龄
passenger_age = T_Survival.pivot_table(index="Pclass",values="Age",aggfunc=np.mean)
print(passenger_age)
print("*"*20)
#总的获救人数的数量
port_stats = T_Survival.pivot_table(index="Embarked",values=["Fare","Survived"],aggfunc=np.sum)
print(port_stats)
print("*"*20)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363
# ********************
#              Fare
# Pclass
# 1       84.154687
# 2       20.662183
# 3       13.675550
# ********************
#               Age
# Pclass
# 1       38.233441
# 2       29.877630
# 3       25.140620
# ********************
#                 Fare  Survived
# Embarked
# C         10072.2962        93
# Q          1022.2543        30
# S         17439.3988       217
# ********************

# %%
#缺失值填充之后再进行数据处理
drop_no_columns = T_Survival.dropna(axis=1)
New_T_Survival = T_Survival.dropna(axis=0,subset=["Age","Sex"])

# %%
row_index_83_age = T_Survival.loc[83,"Age"]
row_index_1000_pclass = T_Survival.loc[766,"Pclass"]
print(row_index_83_age)
print(row_index_1000_pclass)
# Out:
# 28.0
# 1

# %%
new_T_Survival = T_Survival.sort_values("Age",ascending=False)
print(new_T_Survival)
T_reindexed = new_T_Survival.reset_index(drop=True)
print("*"*40)
print(T_reindexed.loc[0:10])
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 493          494         0       1
# 96            97         0       1
# 116          117         0       3
# 672          673         0       2
# 745          746         0       1
# 33            34         0       2
# 54            55         0       1
# 280          281         0       3
# 456          457         0       1
# 438          439         0       1
# 545          546         0       1
# 275          276         1       1
# 483          484         1       3
# 570          571         1       2
# 252          253         0       1
# 829          830         1       1
# 555          556         0       1
# 625          626         0       1
# 326          327         0       3
# 170          171         0       1
# 684          685         0       2
# 694          695         0       1
# 587          588         1       1
# ...

# %%
def hundredth_row(column):
    hundredth_item = column.loc[99]
    return hundredth_item
hundredth_row =T_Survival.apply(hundredth_row)
print(hundredth_row)
# Out:
# PassengerId                  100
# Survived                       0
# Pclass                         2
# Name           Kantor, Mr. Sinai
# Sex                         male
# Age                           34
# SibSp                          1
# Parch                          0
# Ticket                    244367
# Fare                          26
# Cabin                        NaN
# Embarked                       S
# dtype: object

# %%
#对缺省值进行统计
def not_null_count(column):
    column_null = pd.isnull(column)
    null = column[column_null]
    return len(null)
column_null_count = T_Survival.apply(not_null_count)
print(column_null_count)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#对数值进行转换
def which_class(row):
    pclass = row['Pclass']
    if pd.isnull(pclass):
        print("Unknown")
    elif pclass == 1:
        return "First Class"
    elif pclass == 2:
        return "Secound Class"
    elif pclass == 3:
        return "Third Class"

classes = T_Survival.apply(which_class,axis=1)
print(classes)
# Out:
# 0        Third Class
# 1        First Class
# 2        Third Class
# 3        First Class
# 4        Third Class
# 5        Third Class
# 6        First Class
# 7        Third Class
# 8        Third Class
# 9      Secound Class
# 10       Third Class
# 11       First Class
# 12       Third Class
# 13       Third Class
# 14       Third Class
# 15     Secound Class
# 16       Third Class
# 17     Secound Class
# 18       Third Class
# 19       Third Class
# 20     Secound Class
# 21     Secound Class
# 22       Third Class
# 23       First Class
# 24       Third Class
# 25       Third Class
# 26       Third Class
# 27       First Class
# 28       Third Class
# 29       Third Class
#            ...
# 861    Secound Class
# 862      First Class
# 863      Third Class
# 864    Secound Class
# 865    Secound Class
# 866    Secound Class
# 867      First Class
# 868      Third Class
# 869      Third Class
# 870      Third Class
# 871      First Class
# 872      First Class
# ...

# %%
#判断是否为成年人，并且进行标记
def is_minor(row):
    if row["Age"] < 18:
        return True
    else:
        return False

minors = T_Survival.apply(is_minor,axis=1)

def generate_age_label(row):
    age = row["Age"]
    if pd.isnull(age):
        return "unknown"
    elif age < 18:
        return "minor"
    else:
        return "adult"
    
age_labels =T_Survival.apply(generate_age_label,axis=1)
print(age_labels)
# Out:
# 0        adult
# 1        adult
# 2        adult
# 3        adult
# 4        adult
# 5      unknown
# 6        adult
# 7        minor
# 8        adult
# 9        minor
# 10       minor
# 11       adult
# 12       adult
# 13       adult
# 14       minor
# 15       adult
# 16       minor
# 17     unknown
# 18       adult
# 19     unknown
# 20       adult
# 21       adult
# 22       minor
# 23       adult
# 24       minor
# 25       adult
# 26     unknown
# 27       adult
# 28     unknown
# 29     unknown
#         ...
# 861      adult
# 862      adult
# 863    unknown
# 864      adult
# 865      adult
# 866      adult
# 867      adult
# 868    unknown
# 869      minor
# 870      adult
# 871      adult
# 872      adult
# 873      adult
# 874      adult
# 875      minor
# 876      adult
# 877      adult
# 878    unknown
# 879      adult
# 880      adult
# 881      adult
# 882      adult
# 883      adult
# 884      adult
# 885      adult
# 886      adult
# 887      adult
# 888    unknown
# ...

# %%
# 是否成年与年龄之间的关系
T_Survival['age_labels'] = age_labels
age_group_survival =T_Survival.pivot_table(index="age_labels",values ="Survived")
print(age_group_survival)
# Out:
#             Survived
# age_labels
# adult       0.381032
# minor       0.539823
# unknown     0.293785
